# %% [markdown]
# ### Python Basics

# %%
num = 10
height = 9.5
bol = True
name = "Name_not_found"
print(type(num))
print(type(height))
print(type(bol))
print(type(name))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
num_str = str(num)
print(type(num_str))
# Out:
# <class 'str'>

# %% [markdown]
# ## input and output

# %%
inp = input("Enter your name :")
print(f"hello, how are you ? {inp}")
# Out:
# Enter your name : Name_not_found
# hello, how are you ? Name_not_found

# %%
inpt = int(input("Enter the number :"))
print(f"The number you gave as a input is :{inpt}")
